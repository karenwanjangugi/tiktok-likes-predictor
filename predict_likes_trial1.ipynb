# %%
import sqlite3
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score

# %%
with sqlite3.connect('tiktok.db') as conn:
    df = pd.read_sql_query("SELECT * FROM tiktok_data", conn)
    
print(df.head())
# Out:
#    Rank        Username Country Followers  Views   Likes Engagement  \
# 0     1  @charlidamelio   U.S.A     78.9m  38.3m    6.1m     16.60%
# 1     2      @addisonre   U.S.A     53.7m  13.8m    2.8m     20.80%
# 2     3       @zachking   U.S.A     47.3m  17.6m    2.8m        16%
# 3     4      @lorengray   U.S.A     46.3m   3.2m  622.6k     19.70%
# 4     5         @tiktok   U.S.A     45.3m   9.4m  503.0k      5.60%
#
#    Brand Account  Gender   Age   Ethnicity  Famous  \
# 0              0  Female  16.0       White     0.0
# 1              0  Female  19.0       White     0.0
# 2              0    Male  30.0  East Asian     1.0
# 3              0  Female  18.0       White     1.0
# 4              1    None   NaN        None     1.0
#
#                             Genre  LGBTQ
# 0  Dancing, Lipsyncing, Lifestyle    0.0
# 1             Dancing, Lipsyncing    0.0
# 2                Comedy, Illusion    0.0
# 3             Dancing, Lipsyncing    0.0
# 4                            None    NaN

# %%
print(df.columns)
# Out:
# Index(['Rank', 'Username', 'Country', 'Followers', 'Views', 'Likes',
#        'Engagement', 'Brand Account', 'Gender', 'Age', 'Ethnicity', 'Famous',
#        'Genre', 'LGBTQ'],
#       dtype='object')

# %%
df.columns = df.columns.str.lower().str.strip()
print(df.columns)
# Out:
# Index(['rank', 'username', 'country', 'followers', 'views', 'likes',
#        'engagement', 'brand account', 'gender', 'age', 'ethnicity', 'famous',
#        'genre', 'lgbtq'],
#       dtype='object')

# %%
num_cols = df.select_dtypes(include=['int64', 'float']).columns
print(df[num_cols].skew())
# Out:
# rank             0.000000
# followers        3.172300
# likes            3.940735
# brand account    3.781035
# age              2.431823
# famous           0.047165
# lgbtq            4.786310
# dtype: float64

# %%
from sklearn.impute import SimpleImputer

# %%
num_cols = df.select_dtypes(include=['int64', 'float64']).columns
cat_cols = df.select_dtypes(include=['object']).columns

num_imputer = SimpleImputer(strategy='median')
df[num_cols] = num_imputer.fit_transform(df[num_cols])

cat_imputer = SimpleImputer(strategy='most_frequent')
df[cat_cols] = cat_imputer.fit_transform(df[cat_cols])

# %%
df['ethnicity'] = df['ethnicity'].fillna('multiple')
df['gender'] = df['gender'].fillna('not_specific')

print(df['ethnicity'].value_counts())
print(df['gender'].value_counts())
# Out:
# ethnicity
# White              105
# South Asian         62
# Latinx              41
# Black               15
# multiple            14
# East Asian           8
# Southeast Asian      7
# Middle Eastern       4
# Name: count, dtype: int64
# gender
# Male            133
# Female           99
# not_specific     24
# Name: count, dtype: int64

# %%
df['genre'] = df['genre'].fillna('Unknown')

# %%
print(df.isna().sum())
# Out:
# rank             0
# username         0
# country          0
# followers        0
# views            0
# likes            0
# engagement       0
# brand account    0
# gender           0
# age              0
# ethnicity        0
# famous           0
# genre            0
# lgbtq            0
# dtype: int64

# %%
df['gender'].value_counts(dropna=False)
# Out:
# gender
# Male            133
# Female           99
# not_specific     24
# Name: count, dtype: int64

# %%
df[df['gender'].isna()]
# Out:
# Empty DataFrame
# Columns: [rank, username, country, followers, views, likes, engagement, brand account, gender, age, ethnicity, famous, genre, lgbtq]
# Index: []

# %%
bins = [0, 18, 40, 60, 100]
labels = ['young', 'adult', 'middle-aged', 'senior']

df['age_group'] = pd.cut(df['age'], bins=bins, labels=labels)

print(df)
# Out:
#       rank           username country   followers   views      likes  \
# 0      1.0     @charlidamelio   U.S.A  78900000.0   38.3m  6100000.0
# 1      2.0         @addisonre   U.S.A  53700000.0   13.8m  2800000.0
# 2      3.0          @zachking   U.S.A  47300000.0   17.6m  2800000.0
# 3      4.0         @lorengray   U.S.A  46300000.0    3.2m   622600.0
# 4      5.0            @tiktok   U.S.A  45300000.0    9.4m   503000.0
# ..     ...                ...     ...         ...     ...        ...
# 251  252.0  @ramneeksingh1313   India   8600000.0  479.1k    31600.0
# 252  253.0       @amandacerny   U.S.A   8600000.0  654.7k    95200.0
# 253  254.0        @rahimabram  Russia   8600000.0    1.6m   271200.0
# 254  255.0     @johnnyorlando   U.S.A   8600000.0    1.1m   245400.0
# 255  256.0            @sarati   U.S.A   8600000.0  459.5k    90400.0
#
#     engagement  brand account        gender   age    ethnicity  famous  \
# 0       16.60%            0.0        Female  16.0        White     0.0
# 1       20.80%            0.0        Female  19.0        White     0.0
# 2          16%            0.0          Male  30.0   East Asian     1.0
# 3       19.70%            0.0        Female  18.0        White     1.0
# 4        5.60%            1.0  not_specific  22.0     multiple     1.0
# ..         ...            ...           ...   ...          ...     ...
# 251      6.70%            0.0          Male  35.0  South Asian     0.0
# 252     14.60%            0.0        Female  29.0        White     1.0
# 253        17%            0.0          Male  22.0        White     1.0
# 254     22.70%            0.0          Male  17.0        White     1.0
# 255     19.80%            0.0        Female  24.0        White     1.0
#
#                                 genre  lgbtq age_group
# 0      Dancing, Lipsyncing, Lifestyle    0.0     young
# 1                 Dancing, Lipsyncing    0.0     adult
# 2                    Comedy, Illusion    0.0     adult
# 3                 Dancing, Lipsyncing    0.0     young
# 4                             Unknown    0.0     adult
# ..                                ...    ...       ...
# 251                    Comedy, Acting    0.0     adult
# 252                 Comedy, Lifestyle    0.0     adult
# 253  Lipsyncing, Promotion, Lifestyle    0.0     adult
# 254  Lipsyncing, Promotion, Lifestyle    0.0     young
# 255        Dancing, Comedy, Lifestyle    0.0     adult
#
# [256 rows x 15 columns]

# %%
def convert_to_number(x):
    if isinstance(x, str):
        x = x.lower().replace(',','')
        if 'k' in x:
            return float(x.replace('k','')) * 1_000
        elif 'm' in x:
            return float(x.replace('m','')) * 1_000_000
        else:
            return float(x)
    return x

df['likes'] = df['likes'].apply(convert_to_number)
df['followers'] = df['followers'].apply(convert_to_number)

# %%
print(df['likes'].head())
print(df['likes'].dtype)
# Out:
# 0    6100000.0
# 1    2800000.0
# 2    2800000.0
# 3     622600.0
# 4     503000.0
# Name: likes, dtype: float64
# float64

# %%
df['engagement'] = df['engagement'].str.replace('%', '').astype(float)/100.0
df['views'] = df['views'].apply(convert_to_number)

# %%
x = df[['rank','country','engagement','followers','ethnicity','gender','famous','genre', 'views', 'age_group','lgbtq']]
y = df['likes']

genres = x['genre'].str.get_dummies(sep=',')

x = x.drop('genre', axis=1)
x = pd.concat([x,genres], axis=1)

x_encoded = pd.get_dummies(x, drop_first=True)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_encoded, y, test_size=0.2, random_state=42)

linear_model = LinearRegression()
linear_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.ensemble import RandomForestRegressor

rfmodel = RandomForestRegressor(n_estimators=100, random_state=42)
rfmodel.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
from sklearn.model_selection import RandomizedSearchCV

param_dist= {
    'n_estimators': [100,200,300,400,500],
    'max_depth': [None, 10, 20, 30, 40, 50],
    'min_samples_split': [2, 5, 10],
    'max_features': ['sqrt', 'log2', None]
}

rfmodel = RandomForestRegressor(random_state=42)
rf_random = RandomizedSearchCV(
    estimator=rfmodel,
    param_distributions=param_dist,
    n_iter=100,
    cv=3,
    verbose=2,
    random_state=42,
    n_jobs=1
)

rf_random.fit(x_train, y_train)
print("Best parameters found:", rf_random.best_params_)

best_rf = rf_random.best_estimator_

y_pred = best_rf.predict(x_test)
print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
print("R2 score", r2_score(y_test, y_pred)*100)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [CV] END max_depth=None, max_features=None, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=None, max_features=None, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=None, max_features=None, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=10, max_features=None, min_samples_split=2, n_estimators=500; total time=   0.6s
# [CV] END max_depth=10, max_features=None, min_samples_split=2, n_estimators=500; total time=   0.6s
# [CV] END max_depth=10, max_features=None, min_samples_split=2, n_estimators=500; total time=   0.6s
# [CV] END max_depth=20, max_features=None, min_samples_split=5, n_estimators=300; total time=   0.4s
# [CV] END max_depth=20, max_features=None, min_samples_split=5, n_estimators=300; total time=   0.4s
# [CV] END max_depth=20, max_features=None, min_samples_split=5, n_estimators=300; total time=   0.4s
# [CV] END max_depth=40, max_features=log2, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=40, max_features=log2, min_samples_split=2, n_estimators=200; total time=   0.1s
# [CV] END max_depth=40, max_features=log2, min_samples_split=2, n_estimators=200; total time=   0.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=2, n_estimators=300; total time=   0.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=2, n_estimators=300; total time=   0.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=2, n_estimators=300; total time=   0.2s
# [CV] END max_depth=40, max_features=log2, min_samples_split=10, n_estimators=500; total time=   0.4s
# [CV] END max_depth=40, max_features=log2, min_samples_split=10, n_estimators=500; total time=   0.4s
# [CV] END max_depth=40, max_features=log2, min_samples_split=10, n_estimators=500; total time=   0.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=30, max_features=log2, min_samples_split=5, n_estimators=400; total time=   0.3s
# [CV] END max_depth=30, max_features=log2, min_samples_split=5, n_estimators=400; total time=   0.3s
# [CV] END max_depth=30, max_features=log2, min_samples_split=5, n_estimators=400; total time=   0.3s
# [CV] END max_depth=50, max_features=log2, min_samples_split=5, n_estimators=300; total time=   0.2s
# [CV] END max_depth=50, max_features=log2, min_samples_split=5, n_estimators=300; total time=   0.2s
# [CV] END max_depth=50, max_features=log2, min_samples_split=5, n_estimators=300; total time=   0.2s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=2, n_estimators=400; total time=   0.3s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=2, n_estimators=400; total time=   0.3s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=2, n_estimators=400; total time=   0.3s
# [CV] END max_depth=50, max_features=None, min_samples_split=10, n_estimators=400; total time=   0.6s
# [CV] END max_depth=50, max_features=None, min_samples_split=10, n_estimators=400; total time=   0.5s
# [CV] END max_depth=50, max_features=None, min_samples_split=10, n_estimators=400; total time=   0.5s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=2, n_estimators=300; total time=   0.2s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=2, n_estimators=300; total time=   0.2s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=2, n_estimators=300; total time=   0.2s
# [CV] END max_depth=10, max_features=None, min_samples_split=5, n_estimators=300; total time=   0.3s
# [CV] END max_depth=10, max_features=None, min_samples_split=5, n_estimators=300; total time=   0.3s
# [CV] END max_depth=10, max_features=None, min_samples_split=5, n_estimators=300; total time=   0.3s
# [CV] END max_depth=30, max_features=None, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=30, max_features=None, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=30, max_features=None, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=10, n_estimators=500; total time=   0.4s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=10, n_estimators=500; total time=   0.4s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=10, n_estimators=500; total time=   0.4s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=2, n_estimators=200; total time=   0.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=10, n_estimators=500; total time=   0.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=10, n_estimators=500; total time=   0.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=10, n_estimators=500; total time=   0.4s
# [CV] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=40, max_features=None, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_depth=40, max_features=None, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_depth=40, max_features=None, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=50, max_features=None, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_depth=50, max_features=None, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_depth=50, max_features=None, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=200; total time=   0.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=200; total time=   0.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=200; total time=   0.1s
# [CV] END max_depth=None, max_features=None, min_samples_split=10, n_estimators=300; total time=   0.4s
# [CV] END max_depth=None, max_features=None, min_samples_split=10, n_estimators=300; total time=   0.4s
# [CV] END max_depth=None, max_features=None, min_samples_split=10, n_estimators=300; total time=   0.4s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=500; total time=   0.4s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=500; total time=   0.4s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=500; total time=   0.4s
# [CV] END max_depth=None, max_features=log2, min_samples_split=5, n_estimators=300; total time=   0.2s
# [CV] END max_depth=None, max_features=log2, min_samples_split=5, n_estimators=300; total time=   0.2s
# [CV] END max_depth=None, max_features=log2, min_samples_split=5, n_estimators=300; total time=   0.2s
# [CV] END max_depth=40, max_features=log2, min_samples_split=2, n_estimators=500; total time=   0.4s
# [CV] END max_depth=40, max_features=log2, min_samples_split=2, n_estimators=500; total time=   0.4s
# [CV] END max_depth=40, max_features=log2, min_samples_split=2, n_estimators=500; total time=   0.4s
# [CV] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=500; total time=   0.4s
# [CV] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=500; total time=   0.4s
# [CV] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=500; total time=   0.3s
# [CV] END max_depth=None, max_features=log2, min_samples_split=5, n_estimators=500; total time=   0.4s
# [CV] END max_depth=None, max_features=log2, min_samples_split=5, n_estimators=500; total time=   0.4s
# [CV] END max_depth=None, max_features=log2, min_samples_split=5, n_estimators=500; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_split=5, n_estimators=400; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_split=5, n_estimators=400; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_split=5, n_estimators=400; total time=   0.3s
# [CV] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=400; total time=   0.3s
# [CV] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=400; total time=   0.3s
# [CV] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=400; total time=   0.3s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=5, n_estimators=500; total time=   0.4s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=5, n_estimators=500; total time=   0.4s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=5, n_estimators=500; total time=   0.4s
# [CV] END max_depth=40, max_features=None, min_samples_split=10, n_estimators=500; total time=   0.7s
# [CV] END max_depth=40, max_features=None, min_samples_split=10, n_estimators=500; total time=   0.7s
# [CV] END max_depth=40, max_features=None, min_samples_split=10, n_estimators=500; total time=   0.6s
# [CV] END max_depth=50, max_features=log2, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END max_depth=50, max_features=log2, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END max_depth=50, max_features=log2, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=200; total time=   0.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=20, max_features=None, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=20, max_features=None, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=20, max_features=None, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=300; total time=   0.2s
# [CV] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=300; total time=   0.2s
# [CV] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=300; total time=   0.2s
# [CV] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=500; total time=   0.4s
# [CV] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=500; total time=   0.4s
# [CV] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=500; total time=   0.4s
# [CV] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=400; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=400; total time=   0.3s
# [CV] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=400; total time=   0.3s
# [CV] END max_depth=None, max_features=log2, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=log2, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=log2, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, max_features=None, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, max_features=None, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END max_depth=20, max_features=None, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END max_depth=50, max_features=log2, min_samples_split=2, n_estimators=500; total time=   0.4s
# [CV] END max_depth=50, max_features=log2, min_samples_split=2, n_estimators=500; total time=   0.4s
# [CV] END max_depth=50, max_features=log2, min_samples_split=2, n_estimators=500; total time=   0.4s
# [CV] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=500; total time=   0.4s
# [CV] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=500; total time=   0.4s
# [CV] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=500; total time=   0.4s
# [CV] END max_depth=10, max_features=None, min_samples_split=2, n_estimators=300; total time=   0.3s
# [CV] END max_depth=10, max_features=None, min_samples_split=2, n_estimators=300; total time=   0.3s
# [CV] END max_depth=10, max_features=None, min_samples_split=2, n_estimators=300; total time=   0.3s
# [CV] END max_depth=40, max_features=None, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END max_depth=40, max_features=None, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END max_depth=40, max_features=None, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=40, max_features=log2, min_samples_split=10, n_estimators=400; total time=   0.3s
# [CV] END max_depth=40, max_features=log2, min_samples_split=10, n_estimators=400; total time=   0.3s
# [CV] END max_depth=40, max_features=log2, min_samples_split=10, n_estimators=400; total time=   0.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=400; total time=   0.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=400; total time=   0.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=400; total time=   0.3s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=30, max_features=log2, min_samples_split=2, n_estimators=300; total time=   0.2s
# [CV] END max_depth=30, max_features=log2, min_samples_split=2, n_estimators=300; total time=   0.2s
# [CV] END max_depth=30, max_features=log2, min_samples_split=2, n_estimators=300; total time=   0.2s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=5, n_estimators=300; total time=   0.2s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=5, n_estimators=300; total time=   0.2s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=5, n_estimators=300; total time=   0.2s
# [CV] END max_depth=50, max_features=log2, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=50, max_features=log2, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=50, max_features=log2, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=None, min_samples_split=2, n_estimators=400; total time=   0.7s
# [CV] END max_depth=None, max_features=None, min_samples_split=2, n_estimators=400; total time=   0.6s
# [CV] END max_depth=None, max_features=None, min_samples_split=2, n_estimators=400; total time=   0.6s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=2, n_estimators=500; total time=   0.4s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=2, n_estimators=500; total time=   0.4s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=2, n_estimators=500; total time=   0.4s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=5, n_estimators=300; total time=   0.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=5, n_estimators=300; total time=   0.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=5, n_estimators=300; total time=   0.2s
# [CV] END max_depth=40, max_features=log2, min_samples_split=2, n_estimators=300; total time=   0.2s
# [CV] END max_depth=40, max_features=log2, min_samples_split=2, n_estimators=300; total time=   0.2s
# [CV] END max_depth=40, max_features=log2, min_samples_split=2, n_estimators=300; total time=   0.2s
# [CV] END max_depth=None, max_features=None, min_samples_split=5, n_estimators=300; total time=   0.4s
# [CV] END max_depth=None, max_features=None, min_samples_split=5, n_estimators=300; total time=   0.5s
# [CV] END max_depth=None, max_features=None, min_samples_split=5, n_estimators=300; total time=   0.4s
# [CV] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=200; total time=   0.1s
# [CV] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=200; total time=   0.1s
# [CV] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=200; total time=   0.1s
# [CV] END max_depth=10, max_features=None, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, max_features=None, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, max_features=None, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=10, n_estimators=400; total time=   0.3s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=10, n_estimators=400; total time=   0.3s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=10, n_estimators=400; total time=   0.3s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=5, n_estimators=400; total time=   0.3s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=5, n_estimators=400; total time=   0.3s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=5, n_estimators=400; total time=   0.3s
# [CV] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200; total time=   0.1s
# [CV] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200; total time=   0.1s
# [CV] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200; total time=   0.1s
# [CV] END max_depth=50, max_features=log2, min_samples_split=10, n_estimators=400; total time=   0.3s
# [CV] END max_depth=50, max_features=log2, min_samples_split=10, n_estimators=400; total time=   0.3s
# [CV] END max_depth=50, max_features=log2, min_samples_split=10, n_estimators=400; total time=   0.3s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=2, n_estimators=300; total time=   0.2s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=2, n_estimators=300; total time=   0.2s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=2, n_estimators=300; total time=   0.2s
# [CV] END max_depth=10, max_features=log2, min_samples_split=10, n_estimators=400; total time=   0.3s
# [CV] END max_depth=10, max_features=log2, min_samples_split=10, n_estimators=400; total time=   0.3s
# [CV] END max_depth=10, max_features=log2, min_samples_split=10, n_estimators=400; total time=   0.3s
# [CV] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=400; total time=   0.3s
# [CV] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=400; total time=   0.3s
# [CV] END max_depth=None, max_features=log2, min_samples_split=2, n_estimators=400; total time=   0.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END max_depth=40, max_features=log2, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=40, max_features=log2, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=40, max_features=log2, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_split=5, n_estimators=300; total time=   0.2s
# [CV] END max_depth=20, max_features=log2, min_samples_split=5, n_estimators=300; total time=   0.2s
# [CV] END max_depth=20, max_features=log2, min_samples_split=5, n_estimators=300; total time=   0.2s
# [CV] END max_depth=30, max_features=None, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=30, max_features=None, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=30, max_features=None, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, max_features=None, min_samples_split=10, n_estimators=200; total time=   0.3s
# [CV] END max_depth=10, max_features=None, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=10, max_features=None, min_samples_split=10, n_estimators=200; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_split=10, n_estimators=100; total time=   0.1s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=300; total time=   0.2s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=300; total time=   0.2s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=300; total time=   0.2s
# [CV] END max_depth=40, max_features=log2, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=40, max_features=log2, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=40, max_features=log2, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=None, max_features=None, min_samples_split=5, n_estimators=400; total time=   0.6s
# [CV] END max_depth=None, max_features=None, min_samples_split=5, n_estimators=400; total time=   0.6s
# [CV] END max_depth=None, max_features=None, min_samples_split=5, n_estimators=400; total time=   0.5s
# [CV] END max_depth=30, max_features=log2, min_samples_split=2, n_estimators=500; total time=   0.4s
# [CV] END max_depth=30, max_features=log2, min_samples_split=2, n_estimators=500; total time=   0.4s
# [CV] END max_depth=30, max_features=log2, min_samples_split=2, n_estimators=500; total time=   0.4s
# [CV] END max_depth=10, max_features=None, min_samples_split=5, n_estimators=500; total time=   0.6s
# [CV] END max_depth=10, max_features=None, min_samples_split=5, n_estimators=500; total time=   0.5s
# [CV] END max_depth=10, max_features=None, min_samples_split=5, n_estimators=500; total time=   0.5s
# [CV] END max_depth=50, max_features=log2, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END max_depth=50, max_features=log2, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END max_depth=50, max_features=log2, min_samples_split=10, n_estimators=200; total time=   0.1s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=300; total time=   0.2s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=300; total time=   0.2s
# [CV] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=300; total time=   0.2s
# [CV] END max_depth=40, max_features=log2, min_samples_split=5, n_estimators=200; total time=   0.1s
# [CV] END max_depth=40, max_features=log2, min_samples_split=5, n_estimators=200; total time=   0.1s
# [CV] END max_depth=40, max_features=log2, min_samples_split=5, n_estimators=200; total time=   0.2s
# [CV] END max_depth=20, max_features=None, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END max_depth=20, max_features=None, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END max_depth=20, max_features=None, min_samples_split=5, n_estimators=200; total time=   0.3s
# [CV] END max_depth=20, max_features=None, min_samples_split=2, n_estimators=500; total time=   0.7s
# [CV] END max_depth=20, max_features=None, min_samples_split=2, n_estimators=500; total time=   0.7s
# [CV] END max_depth=20, max_features=None, min_samples_split=2, n_estimators=500; total time=   0.7s
# [CV] END max_depth=10, max_features=None, min_samples_split=2, n_estimators=400; total time=   0.4s
# [CV] END max_depth=10, max_features=None, min_samples_split=2, n_estimators=400; total time=   0.5s
# [CV] END max_depth=10, max_features=None, min_samples_split=2, n_estimators=400; total time=   0.4s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=2, n_estimators=200; total time=   0.1s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=2, n_estimators=200; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_split=5, n_estimators=200; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_split=5, n_estimators=200; total time=   0.1s
# [CV] END max_depth=20, max_features=log2, min_samples_split=5, n_estimators=200; total time=   0.1s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=2, n_estimators=500; total time=   0.4s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=2, n_estimators=500; total time=   0.4s
# [CV] END max_depth=50, max_features=sqrt, min_samples_split=2, n_estimators=500; total time=   0.4s
# [CV] END max_depth=50, max_features=None, min_samples_split=2, n_estimators=300; total time=   0.5s
# [CV] END max_depth=50, max_features=None, min_samples_split=2, n_estimators=300; total time=   0.5s
# [CV] END max_depth=50, max_features=None, min_samples_split=2, n_estimators=300; total time=   0.4s
# [CV] END max_depth=50, max_features=None, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END max_depth=50, max_features=None, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=50, max_features=None, min_samples_split=5, n_estimators=100; total time=   0.2s
# [CV] END max_depth=40, max_features=None, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=40, max_features=None, min_samples_split=2, n_estimators=100; total time=   0.2s
# [CV] END max_depth=40, max_features=None, min_samples_split=2, n_estimators=100; total time=   0.1s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=10, n_estimators=400; total time=   0.3s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=10, n_estimators=400; total time=   0.3s
# [CV] END max_depth=40, max_features=sqrt, min_samples_split=10, n_estimators=400; total time=   0.3s
# [CV] END max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100; total time=   0.1s
# [CV] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=500; total time=   0.3s
# [CV] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=500; total time=   0.3s
# [CV] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=500; total time=   0.3s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=300; total time=   0.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=300; total time=   0.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_split=2, n_estimators=300; total time=   0.2s
# [CV] END max_depth=10, max_features=None, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=10, max_features=None, min_samples_split=2, n_estimators=200; total time=   0.2s
# [CV] END max_depth=10, max_features=None, min_samples_split=2, n_estimators=200; total time=   0.3s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=10, n_estimators=300; total time=   0.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_split=10, n_estimators=300; total time=   0.2s
# Best parameters found: {'n_estimators': 100, 'min_samples_split': 5, 'max_features': 'log2', 'max_depth': 40}
# Mean Absolute Error: 422699.7892751991
# R2 score 29.210450915252217

# %%
y_pred = linear_model.predict(x_test)

print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
print("R2 score", r2_score(y_test, y_pred)*100)
# Out:
# Mean Absolute Error: 561187.9290665983
# R2 score 8.686814369599382

# %%
y_pred = rfmodel.predict(x_test)

print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
print("R2 score", r2_score(y_test, y_pred)*100)
# Out:
# Mean Absolute Error: 400484.76923076925
# R2 score 16.403382542344826

# %%
new_data = pd.DataFrame({
    'rank': [25],
    'country': ['Kenya'],
    'engagement': [0.085],
    'followers': [45000],
    'ethnicity': ['African'],
    'gender': ['Female'],
    'famous': ['Yes'],       
    'genre': ['Dance'],
    'lgbtq': ['No']           
})

new_data_encoded = pd.get_dummies(new_data, drop_first=True)
new_data_encoded = new_data_encoded.reindex(columns=x_encoded.columns, fill_value=0)

predicted_likes = int(linear_model.predict(new_data_encoded)[0])
print ("predicted Likes:", predicted_likes)
# Out:
# predicted Likes: -850919

# %%
new_data = pd.DataFrame({
    'rank': [25],
    'country': ['Kenya'],
    'engagement': [0.085],
    'followers': [45000],
    'ethnicity': ['African'],
    'gender': ['Female'],
    'famous': ['Yes'],       
    'genre': ['Dance'],
    'lgbtq': ['No']           
})

new_data_encoded = pd.get_dummies(new_data, drop_first=True)
new_data_encoded = new_data_encoded.reindex(columns=x_encoded.columns, fill_value=0)

predicted_likes = int(rfmodel.predict(new_data_encoded)[0])
print ("predicted Likes:", predicted_likes)
# Out:
# predicted Likes: 245670

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsRegressor

scaler =StandardScaler()
x_scaled = scaler.fit_transform(x_encoded)

x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2, random_state=42)

knn = KNeighborsRegressor(n_neighbors=3)
knn.fit(x_train, y_train)

y_pred = knn.predict(x_test)
print("MAE:", mean_absolute_error(y_test, y_pred))
print("R2:", r2_score(y_test, y_pred)*100)
# Out:
# MAE: 420032.6923076923
# R2: 11.56020343838845

# %%
new_data = pd.DataFrame({
    'rank': [25],
    'country': ['Kenya'],
    'engagement': [0.085],
    'followers': [45000],
    'ethnicity': ['African'],
    'gender': ['Female'],
    'famous': ['Yes'],       
    'genre': ['Dance'],
    'lgbtq': ['No']           
})

new_data_encoded = pd.get_dummies(new_data, drop_first=True)
new_data_encoded = new_data_encoded.reindex(columns=x_encoded.columns, fill_value=0)

predicted_likes = int(knn.predict(new_data_encoded)[0])
print ("predicted Likes:", predicted_likes)
# Out:
# predicted Likes: 2565120
# /home/student/tiktok-sql/tiktokenv/lib/python3.10/site-packages/sklearn/utils/validation.py:2742: UserWarning: X has feature names, but KNeighborsRegressor was fitted without feature names
#   warnings.warn(

# %%
import xgboost as xgb
xgb_model = xgb.XGBRegressor(objective='reg:squarederror', random_state=42)

xgb_model.fit(x_train, y_train)

y_pred_xgb = xgb_model.predict(x_test)

print("XGBoost Model Performance:")
print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred_xgb))
print("R2 score:", r2_score(y_test, y_pred_xgb)*100)
# Out:
# XGBoost Model Performance:
# Mean Absolute Error: 406443.7102050781
# R2 score: 38.49594918396372

# %%
import xgboost as xgb

param_dist_xgb = {
    'n_estimators': [100, 200, 300, 400, 500],
    'max_depth': [3, 4, 5, 6, 7, 8, 9, 10],
    'learning_rate': [0.01, 0.05, 0.1, 0.2],
    'subsample': [0.6, 0.7, 0.8, 0.9, 1.0],
    'colsample_bytree': [0.6, 0.7, 0.8, 0.9, 1.0],
    'gamma': [0, 0.1, 0.2, 0.3],
    'min_child_weight': [1, 2, 3, 4]
}

xgb_model_tuned = xgb.XGBRegressor(objective='reg:squarederror', random_state=42)
xgb_random = RandomizedSearchCV(
    estimator=xgb_model_tuned,
    param_distributions= param_dist_xgb,
    n_iter=100,
    cv=3,
    verbose=2,
    random_state=42,
    n_jobs=1
)


xgb_random.fit(x_train, y_train)
print("Best parametres found:", xgb_random.best_params_)

best_xgb = xgb_random.best_estimator_

y_pred_best_xgb = best_xgb.predict(x_test)

print("\nTuned XGBoost Model Performance:")
print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred_best_xgb))
print("R2 score:", r2_score(y_test, y_pred_best_xgb)*100)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=500, subsample=0.8; total time=   0.5s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=500, subsample=0.8; total time=   0.5s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=500, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.2, max_depth=8, min_child_weight=4, n_estimators=500, subsample=0.6; total time=   0.4s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.2, max_depth=8, min_child_weight=4, n_estimators=500, subsample=0.6; total time=   0.4s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.2, max_depth=8, min_child_weight=4, n_estimators=500, subsample=0.6; total time=   0.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=300, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=300, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.2, max_depth=8, min_child_weight=3, n_estimators=200, subsample=0.9; total time=   0.2s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.2, max_depth=8, min_child_weight=3, n_estimators=200, subsample=0.9; total time=   0.2s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.2, max_depth=8, min_child_weight=3, n_estimators=200, subsample=0.9; total time=   0.2s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.1, max_depth=4, min_child_weight=3, n_estimators=500, subsample=0.6; total time=   0.3s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.1, max_depth=4, min_child_weight=3, n_estimators=500, subsample=0.6; total time=   0.3s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.1, max_depth=4, min_child_weight=3, n_estimators=500, subsample=0.6; total time=   0.3s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.2, max_depth=10, min_child_weight=2, n_estimators=400, subsample=0.9; total time=   0.6s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.2, max_depth=10, min_child_weight=2, n_estimators=400, subsample=0.9; total time=   0.5s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.2, max_depth=10, min_child_weight=2, n_estimators=400, subsample=0.9; total time=   0.5s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.2, max_depth=10, min_child_weight=2, n_estimators=200, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.2, max_depth=10, min_child_weight=2, n_estimators=200, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.2, max_depth=10, min_child_weight=2, n_estimators=200, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=200, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=200, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=200, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=7, min_child_weight=4, n_estimators=300, subsample=0.7; total time=   0.3s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=7, min_child_weight=4, n_estimators=300, subsample=0.7; total time=   0.3s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=7, min_child_weight=4, n_estimators=300, subsample=0.7; total time=   0.4s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.2, max_depth=9, min_child_weight=3, n_estimators=400, subsample=0.6; total time=   0.4s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.2, max_depth=9, min_child_weight=3, n_estimators=400, subsample=0.6; total time=   0.3s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.2, max_depth=9, min_child_weight=3, n_estimators=400, subsample=0.6; total time=   0.4s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=3, min_child_weight=3, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.1, max_depth=5, min_child_weight=4, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.1, max_depth=5, min_child_weight=4, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.1, max_depth=5, min_child_weight=4, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=400, subsample=1.0; total time=   0.4s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=400, subsample=1.0; total time=   0.4s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.1, max_depth=6, min_child_weight=4, n_estimators=400, subsample=1.0; total time=   0.4s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.2, max_depth=6, min_child_weight=3, n_estimators=300, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.2, max_depth=6, min_child_weight=3, n_estimators=300, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.2, max_depth=6, min_child_weight=3, n_estimators=300, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.1, max_depth=10, min_child_weight=4, n_estimators=400, subsample=0.7; total time=   0.4s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.1, max_depth=10, min_child_weight=4, n_estimators=400, subsample=0.7; total time=   0.4s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.1, max_depth=10, min_child_weight=4, n_estimators=400, subsample=0.7; total time=   0.4s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.2, max_depth=10, min_child_weight=4, n_estimators=300, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.2, max_depth=10, min_child_weight=4, n_estimators=300, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.2, max_depth=10, min_child_weight=4, n_estimators=300, subsample=0.9; total time=   0.4s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=2, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=2, n_estimators=200, subsample=0.7; total time=   0.2s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.2, max_depth=4, min_child_weight=2, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.2, max_depth=5, min_child_weight=3, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.2, max_depth=5, min_child_weight=3, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.2, max_depth=5, min_child_weight=3, n_estimators=300, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.9; total time=   0.2s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.9; total time=   0.2s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.2, max_depth=5, min_child_weight=4, n_estimators=400, subsample=0.6; total time=   0.3s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.2, max_depth=5, min_child_weight=4, n_estimators=400, subsample=0.6; total time=   0.3s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.2, max_depth=5, min_child_weight=4, n_estimators=400, subsample=0.6; total time=   0.3s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=300, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=4, n_estimators=300, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=10, min_child_weight=3, n_estimators=400, subsample=1.0; total time=   0.5s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=10, min_child_weight=3, n_estimators=400, subsample=1.0; total time=   0.4s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=10, min_child_weight=3, n_estimators=400, subsample=1.0; total time=   0.4s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.1, max_depth=8, min_child_weight=2, n_estimators=300, subsample=0.6; total time=   0.3s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.1, max_depth=8, min_child_weight=2, n_estimators=300, subsample=0.6; total time=   0.3s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.1, max_depth=8, min_child_weight=2, n_estimators=300, subsample=0.6; total time=   0.3s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.1, max_depth=8, min_child_weight=3, n_estimators=200, subsample=0.6; total time=   0.2s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.1, max_depth=8, min_child_weight=3, n_estimators=200, subsample=0.6; total time=   0.3s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.1, max_depth=8, min_child_weight=3, n_estimators=200, subsample=0.6; total time=   0.4s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.2, max_depth=3, min_child_weight=2, n_estimators=200, subsample=0.9; total time=   0.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.2, max_depth=3, min_child_weight=2, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.2, max_depth=3, min_child_weight=2, n_estimators=200, subsample=0.9; total time=   0.2s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.1, max_depth=8, min_child_weight=1, n_estimators=300, subsample=0.7; total time=   0.3s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.1, max_depth=8, min_child_weight=1, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.1, max_depth=8, min_child_weight=1, n_estimators=300, subsample=0.7; total time=   0.3s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=400, subsample=1.0; total time=   0.4s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=400, subsample=1.0; total time=   0.3s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=400, subsample=1.0; total time=   0.3s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=10, min_child_weight=4, n_estimators=300, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=10, min_child_weight=4, n_estimators=300, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.01, max_depth=10, min_child_weight=4, n_estimators=300, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=10, min_child_weight=3, n_estimators=400, subsample=0.9; total time=   0.4s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=10, min_child_weight=3, n_estimators=400, subsample=0.9; total time=   0.4s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=10, min_child_weight=3, n_estimators=400, subsample=0.9; total time=   0.4s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.2, max_depth=4, min_child_weight=1, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.2, max_depth=4, min_child_weight=1, n_estimators=200, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.2, max_depth=4, min_child_weight=1, n_estimators=200, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.01, max_depth=8, min_child_weight=3, n_estimators=400, subsample=1.0; total time=   0.3s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.01, max_depth=8, min_child_weight=3, n_estimators=400, subsample=1.0; total time=   0.3s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.01, max_depth=8, min_child_weight=3, n_estimators=400, subsample=1.0; total time=   0.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=9, min_child_weight=4, n_estimators=400, subsample=0.9; total time=   0.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=9, min_child_weight=4, n_estimators=400, subsample=0.9; total time=   0.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.2, max_depth=9, min_child_weight=4, n_estimators=400, subsample=0.9; total time=   0.4s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.2, max_depth=10, min_child_weight=4, n_estimators=500, subsample=0.7; total time=   0.5s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.2, max_depth=10, min_child_weight=4, n_estimators=500, subsample=0.7; total time=   0.5s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.2, max_depth=10, min_child_weight=4, n_estimators=500, subsample=0.7; total time=   0.5s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.05, max_depth=8, min_child_weight=4, n_estimators=300, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.05, max_depth=8, min_child_weight=4, n_estimators=300, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.05, max_depth=8, min_child_weight=4, n_estimators=300, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=4, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=4, n_estimators=200, subsample=0.6; total time=   0.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=4, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.2, max_depth=9, min_child_weight=2, n_estimators=200, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.2, max_depth=9, min_child_weight=2, n_estimators=200, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.2, max_depth=9, min_child_weight=2, n_estimators=200, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=3, min_child_weight=3, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.2, max_depth=8, min_child_weight=2, n_estimators=400, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.2, max_depth=8, min_child_weight=2, n_estimators=400, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.2, max_depth=8, min_child_weight=2, n_estimators=400, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=2, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=2, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=2, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.2, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.2, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.2, max_depth=6, min_child_weight=2, n_estimators=500, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.01, max_depth=10, min_child_weight=1, n_estimators=400, subsample=1.0; total time=   0.4s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.01, max_depth=10, min_child_weight=1, n_estimators=400, subsample=1.0; total time=   0.4s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.01, max_depth=10, min_child_weight=1, n_estimators=400, subsample=1.0; total time=   0.5s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.05, max_depth=10, min_child_weight=3, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.05, max_depth=10, min_child_weight=3, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.05, max_depth=10, min_child_weight=3, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=4, n_estimators=300, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=4, n_estimators=300, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=4, n_estimators=300, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.2, max_depth=10, min_child_weight=1, n_estimators=400, subsample=0.9; total time=   0.4s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.2, max_depth=10, min_child_weight=1, n_estimators=400, subsample=0.9; total time=   0.4s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.2, max_depth=10, min_child_weight=1, n_estimators=400, subsample=0.9; total time=   0.4s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.01, max_depth=8, min_child_weight=3, n_estimators=500, subsample=0.9; total time=   0.5s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.01, max_depth=8, min_child_weight=3, n_estimators=500, subsample=0.9; total time=   0.4s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.01, max_depth=8, min_child_weight=3, n_estimators=500, subsample=0.9; total time=   0.4s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=4, n_estimators=500, subsample=1.0; total time=   0.3s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=4, n_estimators=500, subsample=1.0; total time=   0.3s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=4, n_estimators=500, subsample=1.0; total time=   0.3s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=4, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=4, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=4, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=400, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=400, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=400, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=6, min_child_weight=3, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=6, min_child_weight=3, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.2, max_depth=6, min_child_weight=3, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.2, max_depth=5, min_child_weight=4, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.2, max_depth=5, min_child_weight=4, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.2, max_depth=5, min_child_weight=4, n_estimators=200, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=400, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=400, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=400, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.01, max_depth=6, min_child_weight=3, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.01, max_depth=6, min_child_weight=3, n_estimators=200, subsample=0.7; total time=   0.2s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.01, max_depth=6, min_child_weight=3, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.01, max_depth=9, min_child_weight=4, n_estimators=400, subsample=0.6; total time=   0.3s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.01, max_depth=9, min_child_weight=4, n_estimators=400, subsample=0.6; total time=   0.3s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.01, max_depth=9, min_child_weight=4, n_estimators=400, subsample=0.6; total time=   0.3s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=400, subsample=0.6; total time=   0.3s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=400, subsample=0.6; total time=   0.3s
# [CV] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=6, min_child_weight=2, n_estimators=400, subsample=0.6; total time=   0.3s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.2, max_depth=5, min_child_weight=2, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.2, max_depth=5, min_child_weight=2, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.2, max_depth=5, min_child_weight=2, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.2, max_depth=4, min_child_weight=4, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.2, max_depth=4, min_child_weight=4, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.2, max_depth=4, min_child_weight=4, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.05, max_depth=5, min_child_weight=2, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.05, max_depth=5, min_child_weight=2, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.05, max_depth=5, min_child_weight=2, n_estimators=100, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.1, max_depth=10, min_child_weight=4, n_estimators=400, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.1, max_depth=10, min_child_weight=4, n_estimators=400, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.1, max_depth=10, min_child_weight=4, n_estimators=400, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=500, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=500, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=1, n_estimators=500, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.05, max_depth=9, min_child_weight=1, n_estimators=500, subsample=0.7; total time=   0.5s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.05, max_depth=9, min_child_weight=1, n_estimators=500, subsample=0.7; total time=   0.5s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.05, max_depth=9, min_child_weight=1, n_estimators=500, subsample=0.7; total time=   0.4s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.1, max_depth=7, min_child_weight=2, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.1, max_depth=7, min_child_weight=2, n_estimators=200, subsample=0.9; total time=   0.2s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.1, max_depth=7, min_child_weight=2, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.05, max_depth=9, min_child_weight=1, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.05, max_depth=9, min_child_weight=1, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.05, max_depth=9, min_child_weight=1, n_estimators=100, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.05, max_depth=9, min_child_weight=1, n_estimators=400, subsample=0.7; total time=   0.4s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.05, max_depth=9, min_child_weight=1, n_estimators=400, subsample=0.7; total time=   0.3s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.05, max_depth=9, min_child_weight=1, n_estimators=400, subsample=0.7; total time=   0.3s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.05, max_depth=9, min_child_weight=4, n_estimators=500, subsample=0.8; total time=   0.5s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.05, max_depth=9, min_child_weight=4, n_estimators=500, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.05, max_depth=9, min_child_weight=4, n_estimators=500, subsample=0.8; total time=   0.6s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=300, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=300, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.2, max_depth=5, min_child_weight=1, n_estimators=300, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=400, subsample=0.9; total time=   0.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=400, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=400, subsample=0.9; total time=   0.2s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.05, max_depth=6, min_child_weight=1, n_estimators=200, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.05, max_depth=6, min_child_weight=1, n_estimators=200, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.05, max_depth=6, min_child_weight=1, n_estimators=200, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=4, min_child_weight=4, n_estimators=300, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=4, min_child_weight=4, n_estimators=300, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.05, max_depth=4, min_child_weight=4, n_estimators=300, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=2, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=2, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=2, n_estimators=300, subsample=0.9; total time=   0.2s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.05, max_depth=5, min_child_weight=4, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.05, max_depth=5, min_child_weight=4, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.05, max_depth=5, min_child_weight=4, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=500, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=500, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=500, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.01, max_depth=8, min_child_weight=3, n_estimators=200, subsample=0.6; total time=   0.2s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.01, max_depth=8, min_child_weight=3, n_estimators=200, subsample=0.6; total time=   0.2s
# [CV] END colsample_bytree=0.9, gamma=0.3, learning_rate=0.01, max_depth=8, min_child_weight=3, n_estimators=200, subsample=0.6; total time=   0.2s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.1, max_depth=10, min_child_weight=1, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=6, min_child_weight=3, n_estimators=200, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=6, min_child_weight=3, n_estimators=200, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0.1, learning_rate=0.05, max_depth=6, min_child_weight=3, n_estimators=200, subsample=1.0; total time=   0.1s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=3, n_estimators=500, subsample=1.0; total time=   0.3s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=3, n_estimators=500, subsample=1.0; total time=   0.3s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.01, max_depth=4, min_child_weight=3, n_estimators=500, subsample=1.0; total time=   0.3s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.2, max_depth=4, min_child_weight=4, n_estimators=400, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.2, max_depth=4, min_child_weight=4, n_estimators=400, subsample=1.0; total time=   0.2s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.2, max_depth=4, min_child_weight=4, n_estimators=400, subsample=1.0; total time=   0.3s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=400, subsample=0.7; total time=   0.2s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=400, subsample=0.7; total time=   0.2s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=2, n_estimators=400, subsample=0.7; total time=   0.2s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.01, max_depth=10, min_child_weight=1, n_estimators=500, subsample=0.6; total time=   0.4s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.01, max_depth=10, min_child_weight=1, n_estimators=500, subsample=0.6; total time=   0.4s
# [CV] END colsample_bytree=0.8, gamma=0.3, learning_rate=0.01, max_depth=10, min_child_weight=1, n_estimators=500, subsample=0.6; total time=   0.4s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=2, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=2, n_estimators=200, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.8, gamma=0, learning_rate=0.05, max_depth=4, min_child_weight=2, n_estimators=200, subsample=0.7; total time=   0.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=4, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=4, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=10, min_child_weight=4, n_estimators=300, subsample=0.6; total time=   0.2s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.01, max_depth=10, min_child_weight=2, n_estimators=400, subsample=0.9; total time=   0.4s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.01, max_depth=10, min_child_weight=2, n_estimators=400, subsample=0.9; total time=   0.4s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.01, max_depth=10, min_child_weight=2, n_estimators=400, subsample=0.9; total time=   0.4s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.05, max_depth=10, min_child_weight=2, n_estimators=300, subsample=1.0; total time=   0.3s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.05, max_depth=10, min_child_weight=2, n_estimators=300, subsample=1.0; total time=   0.3s
# [CV] END colsample_bytree=0.7, gamma=0.3, learning_rate=0.05, max_depth=10, min_child_weight=2, n_estimators=300, subsample=1.0; total time=   0.3s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.7, gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=200, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=500, subsample=0.7; total time=   0.3s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=500, subsample=0.7; total time=   0.3s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=500, subsample=0.7; total time=   0.3s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.1, max_depth=7, min_child_weight=3, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.1, max_depth=7, min_child_weight=3, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.1, max_depth=7, min_child_weight=3, n_estimators=100, subsample=0.9; total time=   0.1s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=6, min_child_weight=3, n_estimators=500, subsample=0.9; total time=   0.4s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=6, min_child_weight=3, n_estimators=500, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.9, gamma=0.1, learning_rate=0.1, max_depth=6, min_child_weight=3, n_estimators=500, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=9, min_child_weight=1, n_estimators=400, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=9, min_child_weight=1, n_estimators=400, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.7, gamma=0, learning_rate=0.01, max_depth=9, min_child_weight=1, n_estimators=400, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=500, subsample=0.6; total time=   0.3s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=500, subsample=0.6; total time=   0.3s
# [CV] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=4, min_child_weight=4, n_estimators=500, subsample=0.6; total time=   0.3s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=3, n_estimators=200, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=3, n_estimators=200, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.9, gamma=0, learning_rate=0.1, max_depth=10, min_child_weight=3, n_estimators=200, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.01, max_depth=3, min_child_weight=4, n_estimators=400, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.01, max_depth=3, min_child_weight=4, n_estimators=400, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.6, gamma=0.3, learning_rate=0.01, max_depth=3, min_child_weight=4, n_estimators=400, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.05, max_depth=4, min_child_weight=3, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.05, max_depth=4, min_child_weight=3, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END colsample_bytree=0.9, gamma=0.2, learning_rate=0.05, max_depth=4, min_child_weight=3, n_estimators=200, subsample=0.9; total time=   0.1s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.2, max_depth=9, min_child_weight=4, n_estimators=300, subsample=1.0; total time=   0.3s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.2, max_depth=9, min_child_weight=4, n_estimators=300, subsample=1.0; total time=   0.3s
# [CV] END colsample_bytree=1.0, gamma=0.3, learning_rate=0.2, max_depth=9, min_child_weight=4, n_estimators=300, subsample=1.0; total time=   0.3s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=3, n_estimators=500, subsample=0.9; total time=   0.4s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=3, n_estimators=500, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.6, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=3, n_estimators=500, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=4, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=4, n_estimators=100, subsample=0.6; total time=   0.0s
# [CV] END colsample_bytree=0.6, gamma=0.1, learning_rate=0.2, max_depth=3, min_child_weight=4, n_estimators=100, subsample=0.6; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=3, n_estimators=300, subsample=0.7; total time=   0.2s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=3, n_estimators=300, subsample=0.7; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=0, learning_rate=0.01, max_depth=4, min_child_weight=3, n_estimators=300, subsample=0.7; total time=   0.2s
# Best parametres found: {'subsample': 0.9, 'n_estimators': 200, 'min_child_weight': 3, 'max_depth': 3, 'learning_rate': 0.01, 'gamma': 0, 'colsample_bytree': 0.8}
#
# Tuned XGBoost Model Performance:
# Mean Absolute Error: 455533.10817307694
# R2 score: 22.436481630598614

# %%
from sklearn.ensemble import StackingRegressor

estimators = [
    ('rf', rf_random.best_estimator_),
    ('xgb', xgb.XGBRegressor(objective='reg:squarederror', random_state=42))
]

stacking_model = StackingRegressor(
    estimators=estimators,
    final_estimator=LinearRegression(),
    cv=5
)
print('Training the stacking model...')
stacking_model.fit(x_train, y_train)

print("\nStacking Model Performance:")
y_pred_stacking= stacking_model.predict(x_test)
print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred_stacking))
print("R2 score:", r2_score(y_test, y_pred_stacking) * 100)
# Out:
# Training the stacking model...
#
# Stacking Model Performance:
# Mean Absolute Error: 449457.6588483879
# R2 score: 29.449800516048363
